# %%
import pandas as pd

df = pd.read_csv("C:/Users/Dell/Downloads/Titanic-Dataset.csv")

df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
import pandas as pd

# Load dataset from Downloads
df = pd.read_csv("C:/Users/Dell/Downloads/Titanic-Dataset.csv")

# Handle missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Check data
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Survived'].mean()
# Out:
# np.float64(0.3838383838383838)

# %%
df.groupby('Sex')['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Dell/Downloads/Titanic-Dataset.csv")

# Handle missing values
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# Create Age Group column
df['Age Group'] = pd.cut(df['Age'],
                        bins=[0, 12, 18, 35, 60, 100],
                        labels=['Child', 'Teen', 'Young Adult', 'Adult', 'Senior'])

# Groupby
df.groupby('Age Group')['Survived'].mean()
# Out:
# Age Group
# Child          0.579710
# Teen           0.428571
# Young Adult    0.353271
# Adult          0.400000
# Senior         0.227273
# Name: Survived, dtype: float64

# %%
df.groupby('Survived')['Fare'].mean()
# Out:
# Survived
# 0    22.117887
# 1    48.395408
# Name: Fare, dtype: float64

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: numpy<2.8,>=2.0.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scipy) (2.5.0)
# Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    -- ------------------------------------- 2.1/37.3 MB 14.4 MB/s eta 0:00:03
#    ------ --------------------------------- 5.8/37.3 MB 16.2 MB/s eta 0:00:02
#    -------- ------------------------------- 8.4/37.3 MB 15.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.7/37.3 MB 14.3 MB/s eta 0:00:02
#    -------------- ------------------------- 13.1/37.3 MB 13.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.5/37.3 MB 12.7 MB/s eta 0:00:02
#    ------------------ --------------------- 17.6/37.3 MB 12.4 MB/s eta 0:00:02
#    --------------------- ------------------ 20.2/37.3 MB 12.4 MB/s eta 0:00:02
#    ------------------------ --------------- 22.8/37.3 MB 12.5 MB/s eta 0:00:02
#    --------------------------- ------------ 25.7/37.3 MB 12.5 MB/s eta 0:00:01
#    ------------------------------ --------- 28.3/37.3 MB 12.5 MB/s eta 0:00:01
#    --------------------------------- ------ 31.2/37.3 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------ --- 33.8/37.3 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  36.4/37.3 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 12.2 MB/s  0:00:03
# Installing collected packages: scipy
# Successfully installed scipy-1.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.stats import ttest_ind

# %%
male = df[df['Sex']=='male']['Survived']
female = df[df['Sex']=='female']['Survived']

# %%
t_stat, p_value = ttest_ind(male, female)

print("P-value:", p_value)
# Out:
# P-value: 1.4060661308802478e-69
